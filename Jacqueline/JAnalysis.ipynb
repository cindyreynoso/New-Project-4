# %% [markdown]
# ## Do imports, reads in csv, create region dfs

# %%
# the imports
import pandas as pd
from regions import NorthAmerica, CentralAmerica, SouthAmerica, Europe, MiddleEast, SubSaharanAfrica, SouthAsia, SouthEastAsia, EastAsia, Oceania

# %%
# read in the data
mhddd_df = pd.read_csv("../Mental health Depression disorder Data.csv")
mhddd_df.head()
# Out:
#    Unnamed: 0      country code  year  schizophrenia  bipolar_disorder  \
# 0           0  Afghanistan  AFG  1990       0.160560          0.697779
# 1           1  Afghanistan  AFG  1991       0.160312          0.697961
# 2           2  Afghanistan  AFG  1992       0.160135          0.698107
# 3           3  Afghanistan  AFG  1993       0.160037          0.698257
# 4           4  Afghanistan  AFG  1994       0.160022          0.698469
#
#    eating_disorders  anxiety_disorders  drug_use_disorders  depression  \
# 0          0.101855           4.828830            1.677082    4.071831
# 1          0.099313           4.829740            1.684746    4.079531
# 2          0.096692           4.831108            1.694334    4.088358
# 3          0.094336           4.830864            1.705320    4.096190
# 4          0.092439           4.829423            1.716069    4.099582
#
#    alcohol_use_disorders
# 0               0.672404
# 1               0.671768
# 2               0.670644
# ...

# %%
#NorthAmerica, CentralAmerica, SouthAmerica, Europe, MiddleEast, SubSaharanAfrica, SouthAsia, SouthEastAsia, EastAsia, Oceania
NA_df = mhddd_df.loc[mhddd_df["country"].isin(NorthAmerica)]

CA_df = mhddd_df.loc[mhddd_df["country"].isin(CentralAmerica)]

SA_df = mhddd_df.loc[mhddd_df["country"].isin(SouthAmerica)]

EU_df = mhddd_df.loc[mhddd_df["country"].isin(Europe)]

ME_df = mhddd_df.loc[mhddd_df["country"].isin(MiddleEast)]

SSA_df = mhddd_df.loc[mhddd_df["country"].isin(SubSaharanAfrica)]

SAsia_df = mhddd_df.loc[mhddd_df["country"].isin(SouthAsia)]

SEAsia_df = mhddd_df.loc[mhddd_df["country"].isin(SouthEastAsia)]

EAsia_df = mhddd_df.loc[mhddd_df["country"].isin(EastAsia)]

OC_df = mhddd_df.loc[mhddd_df["country"].isin(Oceania)]

# %% [markdown]
# ## Do certain regions have higher rates of mental health percentages?

# %%
#Do certain regions have higher rates of mental health percentages? (e.g. in some countries it might be more socially accepted)

# Create a dataframe with averages across all regions
columns = ["schizophrenia", "bipolar_disorder", "eating_disorders", "anxiety_disorders", "drug_use_disorders", "depression", "alcohol_use_disorders"]

Q1_df = pd.DataFrame(NA_df[columns].mean())
Q1_df = Q1_df.rename({0 : "NorthAmerica"}, axis = 1)

Q1_df["CentralAmerica"] = (CA_df[columns].mean())
Q1_df["SouthAmerica"] = (SA_df[columns].mean())
Q1_df["Europe"] = (EU_df[columns].mean())
Q1_df["MiddleEast"] = (ME_df[columns].mean())
Q1_df["SubSaharanAfrica"] = (SSA_df[columns].mean())
Q1_df["SouthAsia"] = (SAsia_df[columns].mean())
Q1_df["SouthEastAsia"] = (SEAsia_df[columns].mean())
Q1_df["EastAsia"] = (EAsia_df[columns].mean())
Q1_df["Oceania"] = (OC_df[columns].mean())

# %%
Q1a_df = Q1_df.transpose()
Q1a_df
# Out:
#                   schizophrenia  bipolar_disorder  eating_disorders  \
# NorthAmerica           0.326295          0.684859          0.486015
# CentralAmerica         0.199079          0.861691          0.272251
# SouthAmerica           0.196183          0.861865          0.286518
# Europe                 0.234188          0.824157          0.374173
# MiddleEast             0.192891          0.765691          0.190647
# SubSaharanAfrica       0.168161          0.622808          0.123888
# SouthAsia              0.242358          0.564570          0.124727
# SouthEastAsia          0.231138          0.564952          0.206384
# EastAsia               0.259122          0.482778          0.229781
# Oceania                0.244521          0.577830          0.237330
#
#                   anxiety_disorders  drug_use_disorders  depression  \
# NorthAmerica               5.977786            2.497517    4.387049
# CentralAmerica             4.056339            0.771343    2.872367
# ...

# %%
# Include overall average, max, and min
Q1a_df["Average"] = Q1a_df.mean(axis = 1)
Q1a_df["High"] = Q1a_df.max(axis = 1)
Q1a_df["Low"] = Q1a_df.min(axis = 1)
Q1a_df
# Out:
#                   schizophrenia  bipolar_disorder  eating_disorders  \
# NorthAmerica           0.326295          0.684859          0.486015
# CentralAmerica         0.199079          0.861691          0.272251
# SouthAmerica           0.196183          0.861865          0.286518
# Europe                 0.234188          0.824157          0.374173
# MiddleEast             0.192891          0.765691          0.190647
# SubSaharanAfrica       0.168161          0.622808          0.123888
# SouthAsia              0.242358          0.564570          0.124727
# SouthEastAsia          0.231138          0.564952          0.206384
# EastAsia               0.259122          0.482778          0.229781
# Oceania                0.244521          0.577830          0.237330
#
#                   anxiety_disorders  drug_use_disorders  depression  \
# NorthAmerica               5.977786            2.497517    4.387049
# CentralAmerica             4.056339            0.771343    2.872367
# ...

# %%
fig1 = Q1a_df[["Average", "High", "Low"]].plot(kind = "bar")
fig1.set_ylabel("Percent Diagnosed")
fig1.set_title("Aggregate Average, Min, and Max Across all Disorders")
# Out:
# Text(0.5, 1.0, 'Aggregate Average, Min, and Max Across all Disorders')

# %%
fig1a = Q1a_df[["schizophrenia", "bipolar_disorder", "eating_disorders", "anxiety_disorders", 
                "drug_use_disorders", "depression","alcohol_use_disorders"]].plot(kind = "line")
fig1a.set_xlabel("Countries")
fig1a.set_ylabel("Diagnosis")
fig1a.set_title("Average Diagnosis Over Time Per Country")
# Out:
# Text(0.5, 1.0, 'Average Diagnosis Over Time Per Country')

# %%
fig1b = Q1a_df[["anxiety_disorders", "depression", "eating_disorders", "schizophrenia"]].plot(kind = "bar", color = ["red", "brown", "green", "blue"], alpha = 0.7)
fig1a.set_ylabel("Diagnosis")
fig1b.set_title("Disparity Between Highest and Lowest Average Diagnosis Percent")
# Out:
# Text(0.5, 1.0, 'Disparity Between Highest and Lowest Average Diagnosis Percent')

# %% [markdown]
# #### Do certain regions have higher rates of mental health percentages?
#
# According to the dataframe and chart, North America has the highest average mental health diagnosis rate across all time and disorders reaching 2.309 compared to South East Asia's average of 1.258.
#
# North America also has the highest diagnosis rate of 5.9778 in anxiety disorders. In comparison, South East Asia and SubSaharan Africa have the two lowest diagnosis rate in eating disorders.
#
# This means that across all regions, North America has the highest rates of mental health diagnosis above all other regions.
#
# These comparisons are across all disorders, time, and grouped into regions. This is merely a glance at aggregate data that will be further analyzed.
#
# This leads to the question, overall which disorders are plaguing the world the most? The second figure displays diagnosis rates across all regions. It shows that across every region, anxiety disorders and depression have the highest diagnosis rates compared to any other mental health disorder. Whereas on the opposite end, eating disorders and schizophrenia have the lowest diagnosis rates.
#
# The third figure, the bar chart, helps put into perspective how vast the difference is. This could be due to several factors, such as anxiety plaguing the modern world, or a lack of research and attention on eating disorders and schizophrenia. Whatever the reason, the data shows that anxiety and depression are overall some of the most prevalent issues across the entire world.

# %% [markdown]
# ## Does year (time) have an effect on overall mental health diagnosis rates?

# %% [markdown]
# what do I want to do with that?
#
# i want to chart average -schizophrenia diagnosis in Central America over time
# chart average of each mental health diagnosis (anxiety, eating, etc) over time in central america
# show if diagnosis are going up (which is a good and bad thing )
#
# then chart schizophrenia for each region on the same chart

# %%
Q2_df = mhddd_df.groupby("year")
fig2 = Q2_df[columns].mean().plot(kind = "line")
fig2.legend(bbox_to_anchor=(1.0, 1.0))
fig2.set_ylabel("Percent Diagnosed")
fig2.set_title("Average Change in Diagnosis Across the World")
# Out:
# Text(0.5, 1.0, 'Average Change in Diagnosis Across the World')

# %%
temp_df = mhddd_df.groupby("year")
a = temp_df["depression"].mean().plot(kind = "line")
a.legend(bbox_to_anchor=(1.0, 1.0))
a.set_title("A Closer Look at Change in Percent Diagnosed over Time")
# Out:
# Text(0.5, 1.0, 'A Closer Look at Change in Percent Diagnosed over Time')

# %%
#region_dfs = [NA_df, CA_df, SA_df, EU_df, ME_df, SSA_df, SAsia_df, SEAsia_df, EAsia_df, OC_df]
regmin1 = [CA_df, SA_df, EU_df, ME_df, SSA_df, SAsia_df, SEAsia_df, EAsia_df, OC_df]

Q2a_df = NA_df.groupby("year")
Q2a_df = pd.DataFrame(Q2a_df["depression"].mean())

for i in regmin1:
    temp = i.groupby("year")
    temp = temp["depression"].mean()
    Q2a_df[str(i)] = temp

Q2a_df.columns = [["NA", "CA", "SA", "EU", "ME", "SSA", "SAsia", "SEAsia", "EAsia", "OC"]]

Q2a_df = Q2a_df.plot(kind = "line")
Q2a_df.set_ylabel("Depression Rates")
Q2a_df.legend(bbox_to_anchor=(1.0, 1.0))
Q2a_df.set_title("Change in Diagnosis of Depression by Region")
# Out:
# Text(0.5, 1.0, 'Change in Diagnosis of Depression by Region')

# %%
Q2a_df = NA_df.groupby("year")
Q2a_df = pd.DataFrame(Q2a_df["alcohol_use_disorders"].mean())

for i in regmin1:
    temp = i.groupby("year")
    temp = temp["alcohol_use_disorders"].mean()
    Q2a_df[str(i)] = temp

Q2a_df.columns = [["NA", "CA", "SA", "EU", "ME", "SSA", "SAsia", "SEAsia", "EAsia", "OC"]]

Q2a_df = Q2a_df.plot(kind = "line")
Q2a_df.set_ylabel("Alcohol Use Rates")
Q2a_df.legend(bbox_to_anchor=(1.0, 1.0))
Q2a_df.set_title("Change in Diagnosis of Alcohol Use Disorders by Region")
# Out:
# Text(0.5, 1.0, 'Change in Diagnosis of Alcohol Use Disorders by Region')

# %%
Q2a_df = NA_df.groupby("year")
Q2a_df = pd.DataFrame(Q2a_df["schizophrenia"].mean())

for i in regmin1:
    temp = i.groupby("year")
    temp = temp["schizophrenia"].mean()
    Q2a_df[str(i)] = temp

Q2a_df.columns = [["NA", "CA", "SA", "EU", "ME", "SSA", "SAsia", "SEAsia", "EAsia", "OC"]]

Q2a_df = Q2a_df.plot(kind = "line")
Q2a_df.set_ylabel("Schizophrenia Rates")
Q2a_df.legend(bbox_to_anchor=(1.0, 1.0))
Q2a_df.set_title("Change in Diagnosis of Schizophrenia by Region")
# Out:
# Text(0.5, 1.0, 'Change in Diagnosis of Schizophrenia by Region')

# %%
Q2a_df = NA_df.groupby("year")
Q2a_df = pd.DataFrame(Q2a_df["bipolar_disorder"].mean())

for i in regmin1:
    temp = i.groupby("year")
    temp = temp["bipolar_disorder"].mean()
    Q2a_df[str(i)] = temp

Q2a_df.columns = [["NA", "CA", "SA", "EU", "ME", "SSA", "SAsia", "SEAsia", "EAsia", "OC"]]

Q2a_df = Q2a_df.plot(kind = "line")
Q2a_df.set_ylabel("Bipolar Disorder Rates")
Q2a_df.legend(bbox_to_anchor=(1.0, 1.0))
Q2a_df.set_title("Change in Diagnosis of Bipolar Disorder by Region")
# Out:
# Text(0.5, 1.0, 'Change in Diagnosis of Bipolar Disorder by Region')

# %%
Q2a_df = NA_df.groupby("year")
Q2a_df = pd.DataFrame(Q2a_df["eating_disorders"].mean())

for i in regmin1:
    temp = i.groupby("year")
    temp = temp["eating_disorders"].mean()
    Q2a_df[str(i)] = temp

Q2a_df.columns = [["NA", "CA", "SA", "EU", "ME", "SSA", "SAsia", "SEAsia", "EAsia", "OC"]]

Q2a_df = Q2a_df.plot(kind = "line")
Q2a_df.set_ylabel("Eating Disorder Rates")
Q2a_df.legend(bbox_to_anchor=(1.0, 1.0))
Q2a_df.set_title("Change in Diagnosis of Eating Disorders by Region")
# Out:
# Text(0.5, 1.0, 'Change in Diagnosis of Eating Disorders by Region')

# %%
Q2a_df = NA_df.groupby("year")
Q2a_df = pd.DataFrame(Q2a_df["anxiety_disorders"].mean())

for i in regmin1:
    temp = i.groupby("year")
    temp = temp["anxiety_disorders"].mean()
    Q2a_df[str(i)] = temp

Q2a_df.columns = [["NA", "CA", "SA", "EU", "ME", "SSA", "SAsia", "SEAsia", "EAsia", "OC"]]

Q2a_df = Q2a_df.plot(kind = "line")
Q2a_df.set_ylabel("Anxiety Disorder Rates")
Q2a_df.legend(bbox_to_anchor=(1.0, 1.0))
Q2a_df.set_title("Change in Diagnosis of Anxiety Disorders by Region")
# Out:
# Text(0.5, 1.0, 'Change in Diagnosis of Anxiety Disorders by Region')

# %%
Q2a_df = NA_df.groupby("year")
Q2a_df = pd.DataFrame(Q2a_df["drug_use_disorders"].mean())

for i in regmin1:
    temp = i.groupby("year")
    temp = temp["drug_use_disorders"].mean()
    Q2a_df[str(i)] = temp

Q2a_df.columns = [["NA", "CA", "SA", "EU", "ME", "SSA", "SAsia", "SEAsia", "EAsia", "OC"]]

Q2a_df = Q2a_df.plot(kind = "line")
Q2a_df.set_ylabel("Drug Use Disorder Rates")
Q2a_df.legend(bbox_to_anchor=(1.0, 1.0))
Q2a_df.set_title("Change in Diagnosis of Drug Use Disorders by Region")
# Out:
# Text(0.5, 1.0, 'Change in Diagnosis of Drug Use Disorders by Region')

# %% [markdown]
# #### Does year (time) have an effect on overall mental health diagnosis?
#
# How mental health is viewed and treated has greatly changed over time. Factors impacting this include historical events (social, political, or economic), research, social attitudes, and best practices of that time. What is mental health, how its treated, and how its diagnosed changes over time.
#
# Therefore, are there major fluctuations over time? Would diagnoses increase as more awareness is brought up?
#
# The first chart is the average diagnosis rate across every country in the world across time. Thus, it is not very useful. The lines look very flat and as if they change only slightly.
#
# With the y-axis zoomed in, slightly larger fluctuations can be noticed.
#
# Of course, statistics will fluctuate over time. The next question is, which disorder has the largest visual change over time?
#
# Charts for each disorder category were produced.
# On the depression chart, most lines fluctuated between 0.2 range.
# On the alcohol chart, East Asia saw a large increase in alcohol use disorders around 0.4 increase
# Most regions, besides North America, saw a marginal increase in schizophrenia diagnosis. Bipolar disorder has little fluctuation in diagnosis rates.
# Across every region there has been an increase in eating disorders from between 1990 and 2017.
# Anxiety has the largest range of a little more than 2.5, and on the y-axis does show it overall has the highest rates with even the lowest average rates still being above 3.0
# Drug use disorders are highest in North America and have increased more than 0.5 over time, and far outpaces the next highest region the Middle East. Every other country has diagnosis rates below 0.5 compared to North America's above 2.0
#
# From this, we can conjecture both East Asia and North America have seen the largest visual changes in alcohol use and drug use respectively. What caused these should be under study. Further research into these would be useful.

# %% [markdown]
# ## Do certain regions have higher rates of specific mental health diagnoses?

# %% [markdown]
# Put more simply, which regions have high and low rates of each disorder?
#
# Economy, government, culture, and religion all have different impacts on people, including their mental health.
#
# (explain UN's HDI)
#
# When looking at the chart, North America has the highest average depression rates over any other region, but also a high HDI. Yet, right below it in Central America/The Caribbean has some of the lowest average depression rates. Central American countries have a lower HDI, yet they are less depressed than their northern counterparts.
#
# Yet, on the converse, SubSaharan Africa have the second highest average depression rates, with very low HDIs (show map). It seems that HDI may or may not relate to depression rates, as both extremes show differing data.
#
# As for alcohol use rates, Europe has the highest above any other region, and SubSaharan Africa has the lowest along with the Middle East. As most of the Middle East practices Islam, it is not unusual that alcohol (which is considered haram or forbidden). However, SubSaharan Africa with a much lower Muslim population has lower alcohol use disorder rates than the Middle East. What causes this is under speculation as the Middle East again has a higher HDI on average than SubSaharan Africa.
#
# As for schizophrenia, again North America outpaces every other region while SubSaharan Africa has low rates.
#
# As for Bipolar disorders, South Asia and Central America have near identical high rates of bipolar. However these regions are far and very distinct from one another. In comparison, East Asia has very low bipolar rates.
#
# North America and Europe both have the highest eating disorder rates with North America roughly 0.1 higher than even Europe, compared to SubSaharan Africa and South Asia with very low eating disorder rates.
#
# As for anxiety, North America far outpaces every other region by more than 1.0. Whereas East Asia, the Middle East, and SubSaharan Africa have some of the lowest anxiety rates.
#
# Perhaps SubSaharan Africa has such low rates across every chart is because it has a low HDI. Much of SubSaharan Africa are part of industrializing countries, which may not have the means more industrialized countries do to focus on mental health. Or lack of research and resources for mental health in these areas.
#
# In drug use, North America far outpaces every other region. However, the middle east has the second highest drug use, despite drugs being haram and this is an increasing problem. https://www.cnn.com/2022/09/02/middleeast/saudi-drug-capital-mime-intl/index.html. South Asia and SubSaharan Africa both have the lowest reported drug use disorders.
#
# This could also do with culture as North America overall is highly aware of mental health struggles and it is often brought into conversations- whether positively or negatively, it is very open.
#
# https://en.wikipedia.org/wiki/Religion_in_Africa
# https://www.pewresearch.org/religion/2010/04/15/executive-summary-islam-and-christianity-in-sub-saharan-africa/
#
# https://en.wikipedia.org/wiki/Human_Development_Index

# %% [markdown]
# #### Which five countries have the highest/lowest overall percent anxiety diagnosed compared to UN HDI? Is there a correlation?

# %%
mhddd_df["schizophrenia"].max(), mhddd_df["bipolar_disorder"].max(), mhddd_df["eating_disorders"].max(),  mhddd_df["anxiety_disorders"].max(), mhddd_df["drug_use_disorders"].max(),  mhddd_df["depression"].max(),  mhddd_df["alcohol_use_disorders"].max()
# Out:
# (0.37511, 1.206597, 0.943991, 8.96733, 3.452476, 6.602754, 5.474668)

# %%
Q3_df = mhddd_df.loc[mhddd_df["year"]==2017].sort_values(by = "anxiety_disorders", ascending = False)
Q3_df= Q3_df.iloc[0:5]
Q3_df = Q3_df[["country", "anxiety_disorders"]]
Q3_df
# Out:
#             country  anxiety_disorders
# 3471    New Zealand           8.539931
# 3639         Norway           7.585503
# 2295           Iran           6.900900
# 5207  United States           6.635055
# 1735         France           6.626710

# %%
Q3a_df = mhddd_df.loc[mhddd_df["year"] == 2017].sort_values(by = "anxiety_disorders", ascending = False)
Q3a_df = Q3a_df.iloc[191:196]
Q3a_df = Q3a_df[["country", "anxiety_disorders"]]
Q3a_df
# Out:
#          country  anxiety_disorders
# 2631  Kyrgyzstan           2.562742
# 5291  Uzbekistan           2.560435
# 4815  Tajikistan           2.524336
# 1091    Colombia           2.514803
# 5375     Vietnam           2.066871

# %%
# the csv wouldn't read, error with unicode : unicodedecodeerror 'utf-8' codec can't decode byte 0xf4 in position 132167: invalid continuation byte
#added manually from UN website
# https://countryeconomy.com/hdi?year=2017
HDI_anx = [0.935, 0.959, 0.789, 0.924, 0.898, 0.696, 0.715, 0.665, 0.761, 0.692]

# %%
Q3ab_df = pd.merge(Q3_df, Q3a_df, on = ["anxiety_disorders", "country"], how = "outer")
Q3ab_df["UN_HDI"] = HDI_anx
Q3ab_df
# Out:
#          country  anxiety_disorders  UN_HDI
# 0    New Zealand           8.539931   0.935
# 1         Norway           7.585503   0.959
# 2           Iran           6.900900   0.789
# 3  United States           6.635055   0.924
# 4         France           6.626710   0.898
# 5     Kyrgyzstan           2.562742   0.696
# 6     Uzbekistan           2.560435   0.715
# 7     Tajikistan           2.524336   0.665
# 8       Colombia           2.514803   0.761
# 9        Vietnam           2.066871   0.692

# %%
import scipy.stats as st
Q3ab_df.plot(kind = "scatter", x = "UN_HDI", y = "anxiety_disorders", title = "HDI versus Anxiety Disorder Diagnosis")


top5 = Q3ab_df.iloc[0:5]
corr_high = st.pearsonr(top5["UN_HDI"], top5["anxiety_disorders"])
print("The correlation coefficient between HDI and anxiety disorders of the top 5 countries is", round(corr_high[0], 4), "which shows a weak correlation")

bottom5 = Q3ab_df.iloc[5:10]
corr_low = st.pearsonr(bottom5["UN_HDI"], bottom5["anxiety_disorders"])
print("The correlation coefficient between HDI and anxiety disorders of the bottom 5 countries is", round(corr_low[0], 4), "which shows little to no correlation")

corr_all = st.pearsonr(Q3ab_df["UN_HDI"], Q3ab_df["anxiety_disorders"])
print("The correlation coefficient between HDI and anxiety disorders of the top 5 and bottom 5 countries is", round(corr_all[0], 4), "which shows a strong correlation")
# Out:
# The correlation coefficient between HDI and anxiety disorders of the top 5 countries is 0.4162 which shows a weak correlation
# The correlation coefficient between HDI and anxiety disorders of the bottom 5 countries is 0.1892 which shows little to no correlation
# The correlation coefficient between HDI and anxiety disorders of the top 5 and bottom 5 countries is 0.9132 which shows a strong correlation

# %% [markdown]
# #### Which five countries have the highest/lowest overall percent anxiety diagnosed compared to UN HDI? Is there a correlation?
# https://countryeconomy.com/hdi?year=2017
# The Human Development Index(HDI) is a summary measure of average achievement based on: a long and healthy life, being knowledgable, and having a decent standard of living.
#
# There is correlation between HDI and anxiety diagnosis.

# %% [markdown]
# ### Further Analysis Section
# #### Does year (time) have an effect on overall mental health diagnosis?
# Study this by region or by country on an individual basis and cross reference with major events in the country/region
#
# For example, anxiety diagnosis increasing or decreasing the US around major events such as 9/11, the 2008 economic crash, 2020 pandemic
#
# This would need more in-depth analysis
#
# #### Do certain regions have higher rates of specific mental health diagnoses?
# Study different reasons why certain regions have higher rates of disorder
#
# Some factors to look at: economy (gdp), government(stabilty, rights, structure, political division), Hofstede's 5  Cultural Value Dimensions, religion, history
#
# For example, Europe high alcoholism because history of drinking (wine culture in France/Italy, pub culture in England/Ireland)
#
# Study countries on an individual level
#
# #### Which five countries have the highest/lowest overall percent anxiety diagnosed compared to UN HDI? Is there a correlation?
# Study with more data -> get the csv to work
#
# Study over time if correlation is consistent
